# %% [markdown]
# <a href="https://colab.research.google.com/github/juliapachecor/EDP/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100) # Valores de x
y = x**2 # Función y = x^2

plt.plot(x, y) # Graficar
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100) # Valores de x
y = x**2 # Función y = x^2

plt.plot(x, y) # Graficar
plt.xlabel('x')
plt.ylabel('y')
plt.title('')
plt.grid()
plt.show()
plt.show()
